# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo_number_12 = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo_number_12.list_database_names())
# Out:
# ['admin', 'config', 'epa', 'fruits_db', 'local', 'met', 'uk_food']

# %%
# assign the uk_food database to a variable name
uk_db = mongo_number_12['uk_food']
uk_db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'uk_food')

# %%
# review the collections in our new database
print(uk_db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
print(uk_db.establishments.find_one())
# Out:
# {'_id': ObjectId('64c9dfa12ecc43a8ada20496'), 'FHRSID': 1043695, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000073616', 'BusinessName': 'The Pavilion', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': 'East Cliff Pavilion', 'AddressLine2': 'Wear Bay Road', 'AddressLine3': 'Folkestone', 'AddressLine4': 'Kent', 'PostCode': 'CT19 6BL', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2018-04-04T00:00:00', 'LocalAuthorityCode': '188', 'LocalAuthorityName': 'Folkestone and Hythe', 'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk', 'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': Decimal128('1.195625'), 'latitude': Decimal128('51.083812')}, 'RightToReply': '', 'Distance': 4591.765489457773, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T0
# ...

# %%
# assign the collection to a variable
uk_establishments = uk_db['establishments']

# %%
# Create a dictionary for the new restaurant data
new_dining = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}
uk_establishments.insert_one(new_dining)

# %%
# Insert the new restaurant into the collection

# %%
# Check that the new restaurant was inserted
single_query = {'BusinessName': 'Penang Flavours'}
single_results = uk_establishments.find(single_query)
for result in single_results:
    print(result)
# Out:
# {'_id': ObjectId('64c9dfbf2be487e193510740'), 'BusinessName': 'Penang Flavours', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': '1', 'AddressLine1': 'Penang Flavours', 'AddressLine2': '146A Plumstead Rd', 'AddressLine3': 'London', 'AddressLine4': '', 'PostCode': 'SE18 7DY', 'Phone': '', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''}, 'SchemeType': 'FHRS', 'geocode': {'longitude': Decimal128('0.08384000'), 'latitude': Decimal128('51.49014200')}, 'RightToReply': '', 'Distance': 4623.972328074718, 'NewRatingPending': True}
# ...

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
# bus_query = {'BusinessType': 'Restaurant/Cafe/Canteen'}
# bus_results = uk_establishments.find(bus_query)
# for result in uk_establishments.find({"BusinessTypeID","BusinessType"}):
#     print(result)
    
bus_query = {'BusinessType': 'Restaurant/Cafe/Canteen'}
bus_field_results = {'BusinessTypeID': 1, 'BusinessType': 1}

# Capture the results to a variable
bus_results = uk_establishments.find(bus_query, bus_field_results)

# Pretty print the results
for result in bus_results:
    pprint(result)
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64c9dfa12ecc43a8ada20496')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64c9dfa12ecc43a8ada204a1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64c9dfa12ecc43a8ada204a5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64c9dfa12ecc43a8ada204a9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64c9dfa12ecc43a8ada204aa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64c9dfa12ecc43a8ada204b9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64c9dfa12ecc43a8ada204bf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64c9dfa12ecc43a8ada204c2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
# ...

# %%
pprint(uk_establishments.find_one(bus_query, bus_field_results))
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64c9dfa12ecc43a8ada20496')}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
update_value = {'BusinessType': ''}
new_value = {"$set":{"BusinessTypeID":"1"}}

uk_establishments.update_one(single_query,new_value)

# %%
# Confirm that the new restaurant was updated

update_query = {"BusinessName":"Penang Flavours"}
update_fields_check = {"BusinessName": 1, 'BusinessTypeID': 1}

# Capture the results to a variable
update_results = uk_establishments.find_one(update_query, update_fields_check)

# # Pretty print the results
# for result in update_results:
#     pprint(result)
pprint(update_results)
# Out:
# {'BusinessName': 'Penang Flavours',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('64c9dfbf2be487e193510740')}

# %%
# pprint(uk_establishments.find_one({"BusinessName":"Penang Flavours"}))

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
dover_query = {'LocalAuthorityName': "Dover"}

print("Number of documents with a Local Authority Name equal to Dover is", uk_establishments.count_documents(dover_query))
# Out:
# Number of documents with a Local Authority Name equal to Dover is 0

# %%
# Delete all documents where LocalAuthorityName is "Dover"
dover_delete_query = {'LocalAuthorityName': 'Dover'}
uk_establishments.delete_many(dover_delete_query)
dover_delete_results = uk_establishments.find(dover_delete_query)
for result in dover_delete_results:
    print(result)

# %%
# Check if any remaining documents include Dover
print("Number of documents with a Local Authority Name equal to Dover is", uk_establishments.count_documents(dover_query))
# Out:
# Number of documents with a Local Authority Name equal to Dover is 0

# %%
# Check that other documents remain with 'find_one'
dovers_check = uk_establishments.find_one({'LocalAuthorityName':{"$ne":'Dover'}})
print(dovers_check)
# Out:
# {'_id': ObjectId('64c9dfa12ecc43a8ada20496'), 'FHRSID': 1043695, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000073616', 'BusinessName': 'The Pavilion', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': 'East Cliff Pavilion', 'AddressLine2': 'Wear Bay Road', 'AddressLine3': 'Folkestone', 'AddressLine4': 'Kent', 'PostCode': 'CT19 6BL', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2018-04-04T00:00:00', 'LocalAuthorityCode': '188', 'LocalAuthorityName': 'Folkestone and Hythe', 'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk', 'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': Decimal128('1.195625'), 'latitude': Decimal128('51.083812')}, 'RightToReply': '', 'Distance': 4591.765489457773, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T0
# ...

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
uk_establishments.update_many({}, [{'$set': {'geocode.longitude': {'$toDecimal': '$geocode.longitude'}}}])
uk_establishments.update_many({}, [{'$set': {'geocode.latitude': {'$toDecimal': '$geocode.latitude'}}}])

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
uk_establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
uk_establishments.update_many({}, [{'$set': {'RatingValue':{'$toInt': '$RatingValue'}}}])

# %%
# Check that the coordinates and rating value are now numbers
pprint(uk_establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64c9dfa12ecc43a8ada20496'),
#  'geocode': {'latitude': Decimal128('51.083812'),
#              'longitude': Decimal128('1.195625')},
# ...
